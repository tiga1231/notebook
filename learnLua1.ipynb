-- %%
s = 'the anthem ias the theme123'
reg = '%f[%w]the%f[%W]' --frontier pattern

ss = string.gsub(s, reg, '___')
print(s)
print(ss)

--[[
for i in string.gmatch(s, reg) do
    s = string.gsub(s, reg, string.rep('_', #i), 1)
    print(i, s)
end
]]--
-- Out:
-- the anthem ias the theme123
-- _________ __________________ _________ _________ ________________________

-- %%
s = 'the anthemee ias bbbcc the theme123'
reg = '(%w)(%w)(%2)' --captures() and %2nd capture
print(string.match(s, reg))
-- Out:
-- m	e	e

-- %%
function sum(...)
    local ret = 0
    print(select("#", ...))
    for i = 1, select("#", ...) do 
        ret = ret + select(i, ...)
    end
    return ret
end

-- %%
print(_G)
-- Out:
-- {
--   coroutine :
--     {
--       wrap : function: 0x103a1e090
--       create : function: 0x103a1de90
--       resume : function: 0x103a1dee0
--       running : function: 0x103a1df80
--       status : function: 0x103a1dfb0
--       yield : function: 0x103a1e0f0
--     }
--   torchtest_isSetTo : function: 0x7ffc0af26dc0
--   type : function: 0x7ffc0ac27a80
--   _PROMPT : t7>
--   torchtest_repeatTensor : function: 0x7ffc0af26cf0
--   _PROMPT2 : . >
--   debug :
--     {
--       getuservalue : function: 0x103a1e440
--       traceback : function: 0x103a1f260
--       setlocal : function: 0x103a1f070
--       getmetatable : function: 0x103a1eb20
--       getregistry : function: 0x103a1eb00
--       upvaluejoin : function: 0x103a1ebe0
--       getinfo : function: 0x103a1e5a0
--       setmetatable : function: 0x103a1f180
--       sethook : function: 0x103a1eec0
--       debug : function: 0x103a1e2c0
--       setuservalue : function: 0x103a1ee30
-- ...

-- %%
print(_G['itorch'])
-- Out:
-- {
--   demo : function: 0x7ffc0ad4d430
--   _iopub : LuaZMQ: Socket[PAIR] (0x7ffc0ae47bd8)
--   svg : function: 0x7ffc0ad4d950
--   Plot :
--     {
--       triangle : function: 0x7ffc0af6a520
--       circle : function: 0x7ffc0af6a420
--       yaxis : function: 0x7ffc0af6a7b0
--       quiver : function: 0x7ffc0af6a8f0
--       histogram : function: 0x7ffc0af6a780
--       hover_tool : function: 0x7ffc0af6a7f0
--       text : function: 0x7ffc0af6a750
--       line : function: 0x7ffc0af6a4e0
--       redraw : function: 0x7ffc0ac59860
--       _toAllModels : function: 0x7ffc0af6b100
--       save : function: 0x7ffc0ac599b0
--       title : function: 0x7ffc0af6a4c0
--       toHTML : function: 0x7ffc0ac59830
--       toTemplate : function: 0x7ffc0ac597c0
--       gscatter : function: 0x7ffc0af6a490
--       legend : function: 0x7ffc0af6a7d0
--       new : function: 0x7ffc0af694f0
--       draw : function: 0x7ffc0ac59950
--       segment : function: 0x7ffc0af6a8c0
-- ...
